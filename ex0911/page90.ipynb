# %%
from openai import OpenAI

# %%
client = OpenAI()

response = client.responses.create(
    model="gpt-5-mini",
    input="대한민국 수도"
)

# %%
print(response.output_text)
# Out:
# 대한민국의 수도는 서울특별시(Seoul)입니다. 다만 일부 행정기능(정부 부처 일부)은 세종특별자치시로 이전해 운영되고 있습니다.

# %%
print(response)
