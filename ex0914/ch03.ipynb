# %%
#가상환경 위치확인 
#!pip --version
# Out:
# pip 25.0.1 from D:\yujin0902\ex0914\.venv\Lib\site-packages\pip (python 3.12)

# %%
#dotenv 설치라이브러리
#!pip install dotenv

# %%
from dotenv import load_dotenv

# .env 파일 로드: 키 값을 읽었음을 표시 True
load_dotenv()
# Out:
# True

# %%
import os

#key 값을 출력

print(f"키 값은: {os.environ['OPENAI_API_KEY'][:8]}")
# Out:
# 키 값은: sk-proj-
